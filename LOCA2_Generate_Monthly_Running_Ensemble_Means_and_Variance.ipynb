# %% [markdown]
# # Loca2 Generate Monthly Running Means and Variance Files

# %%
##########################################################
#
# Library Calls.
#

print("")
print("###########################")
print("Load Libraries and Utility Functions")

import numpy      as np
import xarray     as xr
import zarr       as zarr
import dask       as da
import h5netcdf   as h5netcdf
import datetime   as datetime
import os         as os
import subprocess as subprocess
import dask       as dask

try:
    get_ipython()
    am_iPython = True
    print("Code is running in a Jupyter/IPython environment.")
except NameError:
    am_iPython = False
    print("Code is running in a standard Python environment (CLI/script).")

def showme(x):
    if am_iPython:
        display(x)
    else:
        print(x)

print("###########################")
print("")
#
##########################################################
# Out:
# ###########################
# Load Libraries and Utility Functions
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 11
#       8 print("Load Libraries and Utility Functions")
#      10 import numpy      as np
# ---> 11 import xarray     as xr
#      12 import zarr       as zarr
#      13 import dask       as da
#
# File ~/miniforge3/lib/python3.12/site-packages/xarray/__init__.py:3
#       1 from importlib.metadata import version as _version
# ----> 3 from xarray import coders, groupers, indexes, testing, tutorial, ufuncs
#       4 from xarray.backends.api import (
#       5     load_dataarray,
#       6     load_dataset,
#    (...)     12     open_mfdataset,
#      13 )
#      14 from xarray.backends.writers import save_mfdataset
#
# File ~/miniforge3/lib/python3.12/site-packages/xarray/coders.py:6
#       1 """
#       2 This module provides coder objects that encapsulate the
#       3 "encoding/decoding" process.
#       4 """
# ----> 6 from xarray.coding.times import CFDatetimeCoder, CFTimedeltaCoder
#       8 __all__ = ["CFDatetimeCoder", "CFTimedeltaCoder"]
#
# File ~/miniforge3/lib/python3.12/site-packages/xarray/coding/times.py:12
#       9 from typing import TYPE_CHECKING, Union, cast
#      11 import numpy as np
# ---> 12 import pandas as pd
#      13 from pandas.errors import OutOfBoundsDatetime, OutOfBoundsTimedelta
#      15 from xarray.coding.common import (
#      16     SerializationWarning,
#      17     VariableCoder,
#    (...)     22     unpack_for_encoding,
#      23 )
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/__init__.py:26
#      22 del _hard_dependencies, _dependency, _missing_dependencies
#      24 try:
#      25     # numpy compat
# ---> 26     from pandas.compat import (
#      27         is_numpy_dev as _is_numpy_dev,  # pyright: ignore[reportUnusedImport] # noqa: F401
#      28     )
#      29 except ImportError as _err:  # pragma: no cover
#      30     _module = _err.name
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/compat/__init__.py:29
#      27 import pandas.compat.compressors
#      28 from pandas.compat.numpy import is_numpy_dev
# ---> 29 from pandas.compat.pyarrow import (
#      30     HAS_PYARROW,
#      31     pa_version_under10p1,
#      32     pa_version_under11p0,
#      33     pa_version_under13p0,
#      34     pa_version_under14p0,
#      35     pa_version_under14p1,
#      36     pa_version_under16p0,
#      37     pa_version_under17p0,
#      38     pa_version_under18p0,
#      39     pa_version_under19p0,
#      40     pa_version_under20p0,
#      41     pa_version_under21p0,
#      42 )
#      44 if TYPE_CHECKING:
#      45     from pandas._typing import F
#
# File ~/miniforge3/lib/python3.12/site-packages/pandas/compat/pyarrow.py:8
#       5 from pandas.util.version import Version
#       7 try:
# ----> 8     import pyarrow as pa
#      10     _palv = Version(Version(pa.__version__).base_version)
#      11     pa_version_under10p1 = _palv < Version("10.0.1")
#
# File ~/miniforge3/lib/python3.12/site-packages/pyarrow/__init__.py:61
#      58     except ImportError:
#      59         __version__ = None
# ---> 61 import pyarrow.lib as _lib
#      62 from pyarrow.lib import (BuildInfo, CppBuildInfo, RuntimeInfo, set_timezone_db_path,
#      63                          MonthDayNano, VersionInfo, build_info, cpp_build_info,
#      64                          cpp_version, cpp_version_info, runtime_info,
#      65                          cpu_count, set_cpu_count, enable_signal_handlers,
#      66                          io_thread_count, set_io_thread_count)
#      69 def show_versions():
#
# File <frozen importlib._bootstrap>:645, in parent(self)
#
# KeyboardInterrupt:

# %%
##########################################################
#
# Files
#

print("")
print("###########################")
print("Read File Address Information")

mask_file     = "https://thredds.ias.sdsmt.edu:8443/thredds/dodsC/LOCA2/loca2_mask.nc"
climtime_file = "https://thredds.ias.sdsmt.edu:8443/thredds/dodsC/LOCA2/Climate_CONUS/Monthly/metadata_netcdf_files/climatology_bounds.nc"
scenario_file = "https://thredds.ias.sdsmt.edu:8443/thredds/dodsC/LOCA2/Climate_CONUS/Monthly/metadata_netcdf_files/scenarios.nc" 
ensemble_file = "https://thredds.ias.sdsmt.edu:8443/thredds/dodsC/LOCA2/Climate_CONUS/Monthly/metadata_netcdf_files/model_member.nc" 

root_data_dir = "/data/DATASETS/LOCA_MACA_Ensembles/LOCA2/LOCA2_CONUS/Climate_CONUS/Monthly/"


mf_tasmax = [root_data_dir + 'historical/LOCA2-CONUS-ANNUAL30YRUNMEAN_MONTHLYMEAN___tasmax___ALLRANK01___historical.nc',
             root_data_dir +     'ssp245/LOCA2-CONUS-ANNUAL30YRUNMEAN_MONTHLYMEAN___tasmax___ALLRANK01___ssp245.nc',
             root_data_dir +     'ssp370/LOCA2-CONUS-ANNUAL30YRUNMEAN_MONTHLYMEAN___tasmax___ALLRANK01___ssp370.nc',
             root_data_dir +     'ssp585/LOCA2-CONUS-ANNUAL30YRUNMEAN_MONTHLYMEAN___tasmax___ALLRANK01___ssp585.nc']

mf_tasmin = [root_data_dir + 'historical/LOCA2-CONUS-ANNUAL30YRUNMEAN_MONTHLYMEAN___tasmin___ALLRANK01___historical.nc',
             root_data_dir +     'ssp245/LOCA2-CONUS-ANNUAL30YRUNMEAN_MONTHLYMEAN___tasmin___ALLRANK01___ssp245.nc',
             root_data_dir +     'ssp370/LOCA2-CONUS-ANNUAL30YRUNMEAN_MONTHLYMEAN___tasmin___ALLRANK01___ssp370.nc',
             root_data_dir +     'ssp585/LOCA2-CONUS-ANNUAL30YRUNMEAN_MONTHLYMEAN___tasmin___ALLRANK01___ssp585.nc']

mf_pr     = [root_data_dir + 'historical/LOCA2-CONUS-ANNUAL30YRUNMEAN_MONTHLYSUM___pr___ALLRANK01___historical.nc',
             root_data_dir +     'ssp245/LOCA2-CONUS-ANNUAL30YRUNMEAN_MONTHLYSUM___pr___ALLRANK01___ssp245.nc',
             root_data_dir +     'ssp370/LOCA2-CONUS-ANNUAL30YRUNMEAN_MONTHLYSUM___pr___ALLRANK01___ssp370.nc',
             root_data_dir +     'ssp585/LOCA2-CONUS-ANNUAL30YRUNMEAN_MONTHLYSUM___pr___ALLRANK01___ssp585.nc']

print("###########################")
print("")

#
##########################################################

# %%
##########################################################
#
# Read Metadata Files
#

print("")
print("###########################")
print("Open Mask and Coordinate Data")

mask_file     = "https://thredds.ias.sdsmt.edu:8443/thredds/dodsC/LOCA2/loca2_mask.nc"
climtime_file = "https://thredds.ias.sdsmt.edu:8443/thredds/dodsC/LOCA2/Climate_CONUS/Monthly/metadata_netcdf_files/climatology_bounds.nc"
scenario_file = "https://thredds.ias.sdsmt.edu:8443/thredds/dodsC/LOCA2/Climate_CONUS/Monthly/metadata_netcdf_files/scenarios.nc" 
ensemble_file = "https://thredds.ias.sdsmt.edu:8443/thredds/dodsC/LOCA2/Climate_CONUS/Monthly/metadata_netcdf_files/model_member.nc" 

print("--------------------------")
print("Pulling Surface Mask")

ds_mask = xr.open_dataset(mask_file)
mask    = ds_mask["loca2_mask"]

showme(mask)

print("--------------------------")

print("###########################")
print("")

#
##########################################################
